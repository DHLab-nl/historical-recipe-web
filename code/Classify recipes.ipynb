# %% [markdown]
# # Building classifier for recipes

# %% [markdown]
# I actually trained the classifier using the python file 'classify_recipes.py'.
# If you want to do it in a notebook locally go ahead, it's going to take some time.
# The output of the classifier can be found in the files 'output_classifier.txt'

# %%
import pandas as pd
from sklearn.externals import joblib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import precision_score
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.multiclass import OneVsRestClassifier
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score
from sklearn.utils import shuffle
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_pickle('./data/recipe_dataset.pkl')
dataset['type_id'] = dataset['type'].factorize()[0]
category_id_df = dataset[['type', 'type_id']].drop_duplicates().sort_values('type_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['type_id', 'type']].values)
labels = ['articles', 'recipes']

# %%
# prepare features
X = dataset['ocr_without_stopwords']
y = dataset['type'].values

# %%
# shuffle dataset
X_shuf, y_shuf = shuffle(X, y)
X_train, X_test, y_train, y_test = train_test_split(X_shuf, y_shuf, test_size=0.3, random_state=1)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (11853,) (5081,) (11853,) (5081,)

# %% [markdown]
# ## Naive Bayes

# %%
# Naive Bayes
# initialize classifier
NB_clf = Pipeline([
	('tfidf', TfidfVectorizer(min_df=5, max_df=0.9, sublinear_tf=True, ngram_range=(1,2), analyzer='word')),
	('clf', MultinomialNB())])

params = {
	'tfidf__min_df': (0, 5, 10),
	'tfidf__max_df': (0.25, 0.50, 0.75, 0.90),
	'tfidf__analyzer': ['word'],
	'tfidf__ngram_range': [(1,1), (1,2), (1,3), (1,4), (1,5), (2, 2), (2, 3), (2, 4), (2,5), (2,6), (3,3), (3,4), (3,5)],
	'tfidf__use_idf': (True, False),
	'clf__alpha': (1e-2, 1e-3)
}

# %%
# Random Search for hyper-parameters
NB_randsearch = RandomizedSearchCV(NB_clf, param_distributions=params, n_iter=50, cv=5, n_jobs=30, verbose=3)
NB_randsearch.fit(X_train, y_train)

joblib.dump(NB_randsearch, 'NB_clf.pkl')

# %%
print("Naive Bayes Best Score:{}".format(NB_randsearch.best_score_))
print("Naive Bayes Best Params:{}".format(NB_randsearch.best_params_))

NB_pred = NB_randsearch.predict(X_test)

print("Accuracy Naive Bayes: {}".format(accuracy_score(y_test, NB_pred)))
scores = {}
scores['precision'] = precision_score(y_test, NB_pred, average=None)
scores['recall'] = recall_score(y_test, NB_pred, average=None)
scores['f1'] = f1_score(y_test, NB_pred, average=None)
print("Naive Bayes Precision/Recall/F1 Score:")
print("-" * 80)
print(pd.DataFrame(data=scores, index=labels))

# %% [markdown]
# # SVM

# %%
# SVM classifier
# Initialize classifier
SVM_clf = Pipeline([('tfidf', TfidfVectorizer(min_df=5, max_df=0.75, sublinear_tf=True, ngram_range=(1, 2), analyzer='word')),
						 ('clf-svm', SGDClassifier(alpha=1e-3, random_state=42))])


params = {
	'tfidf__min_df': (0, 5),
	'tfidf__max_df': (0.50, 0.75, 0.90),
	'tfidf__analyzer': ['word'],
	'tfidf__ngram_range': [(1, 1), (1,2), (1, 3), (1,4), (1,5), (2, 2), (2, 3), (2, 4), (2,5), (3,3), (3,4), (3,5)],
	'clf-svm__alpha': (1e-2, 1e-3)
}

# %%
# Random Search for hyper-parameters SVM
svm_randsearch = RandomizedSearchCV(SVM_clf, param_distributions=params, n_iter=50, cv=5, n_jobs=30,
								random_state=333, verbose=3)

svm_randsearch.fit(X_train, y_train)
joblib.dump(svm_randsearch, 'SVM_clf.pkl')

# %%
print("SVM Best Score:{}".format(svm_randsearch.best_score_))
print("SVM Best Params:{}".format(svm_randsearch.best_params_))

SVM_pred = svm_randsearch.predict(X_test)

print("Accuracy SVM: {}".format(accuracy_score(y_test, SVM_pred)))
scores = {}
scores['precision'] = precision_score(y_test, SVM_pred, average=None)
scores['recall'] = recall_score(y_test, SVM_pred, average=None)
scores['f1'] = f1_score(y_test, SVM_pred, average=None)
print("SVM Precision/Recall/F1 Score:")
print("-" * 80)
print(pd.DataFrame(data=scores, index=labels))

# %% [markdown]
# # SVC

# %%
# SVC classifier
# Initialize Linear SVC Classifier
SVC_clf = Pipeline([
	('tfidf', TfidfVectorizer(min_df=5, max_df=0.75, sublinear_tf=True, ngram_range=(1,2), analyzer='word')),
	('svc-clf', OneVsRestClassifier(LinearSVC(verbose=True, class_weight='balanced', C=1.0)))])


params = {
	'tfidf__min_df': (0, 5),
	'tfidf__max_df': (0.50, 0.75, 0.90),
	'tfidf__analyzer': ['word'],
	'tfidf__ngram_range': [(1, 1), (1, 2), (1, 3), (1, 4), (1,5), (2, 2), (2, 3), (2, 4), (2, 5), (3, 3), (3, 4), (3, 5)],
}

# Random Search for hyper-parameters
svc_randsearch = RandomizedSearchCV(SVC_clf, param_distributions=params,
									n_iter=50, cv=5, n_jobs=30,
									random_state=333, verbose=3)

svc_randsearch.fit(X_train, y_train)
joblib.dump(svc_randsearch, 'SVC_clf.pkl')

# %%
svc_randsearch = joblib.load('models/SVC_clf.pkl')

# %%
# Random Search for hyper-parameters
svc_randsearch = RandomizedSearchCV(SVC_clf, param_distributions=params,
									n_iter=50, cv=5, n_jobs=30,
									random_state=333, verbose=3)

svc_randsearch.fit(X_train, y_train)
joblib.dump(svc_randsearch, 'SVC_clf.pkl')

# %%
print("SVM Best Score:{}".format(svc_randsearch.best_score_))
print("SVM Best Params:{}".format(svc_randsearch.best_params_))

SVC_pred = svc_randsearch.predict(X_test)

print("Accuracy SVC: {}".format(accuracy_score(y_test, SVC_pred)))
scores = {}
scores['precision'] = precision_score(y_test, SVC_pred, average=None)
scores['recall'] = recall_score(y_test, SVC_pred, average=None)
scores['f1'] = f1_score(y_test, SVC_pred, average=None)
print("SVC Precision/Recall/F1 Score:")
print("-" * 80)
print(pd.DataFrame(data=scores, index=labels))
pd.DataFrame(data=scores, index=labels).to_latex
# Out:
# SVM Best Score:0.9627942293090357
# SVM Best Params:{'tfidf__max_df': 0.5, 'tfidf__min_df': 5, 'tfidf__analyzer': 'word', 'tfidf__ngram_range': (1, 2)}
# Accuracy SVC: 0.9866168077150167
# SVC Precision/Recall/F1 Score:
# --------------------------------------------------------------------------------
#                 f1  precision    recall
# articles  0.987761   0.985632  0.989899
# recipes   0.985237   0.987810  0.982676
# <bound method NDFrame.to_latex of                 f1  precision    recall
# articles  0.987761   0.985632  0.989899
# recipes   0.985237   0.987810  0.982676>

# %%
print(pd.DataFrame(data=scores, index=labels).to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
# {} &        f1 &  precision &    recall \\
# \midrule
# articles &  0.987761 &   0.985632 &  0.989899 \\
# recipes  &  0.985237 &   0.987810 &  0.982676 \\
# \bottomrule
# \end{tabular}

# %%
conf_mat = confusion_matrix(y_test, SVC_pred)
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=category_id_df.type.values, yticklabels=category_id_df.type.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title("Confusion Matrix Naive Bayes")
plt.savefig("confusion_matrix_nb.png")

# %% [markdown]
# # Tag Recipes in Newspapers

# %%
import glob

# %%
def load_df(name):
    '''
    options for names include trouw, volkskrant, parool, or nrc
    '''
    
    path = 'data/' + name
    allFiles = glob.glob(path + "/*.tsv")
    if name == 'nrc':
        df = pd.concat((pd.read_csv(f, delimiter='\t') for f in allFiles))
    else:
        df = pd.concat((pd.read_csv(f, delimiter='\t', header=None) for f in allFiles))
        df.columns = ['date', 'page', 'size', 'min_x', 'min_y', 'max_x', 'max_y', 'w', 'h', 'image_url', 'ocr_url', 'ocr']
    print("imported " + name + " articles")
    drop_cols = ['min_x', 'min_y', 'max_x', 'max_y', 'image_url']
    df = df.drop(drop_cols, axis=1)
    df = df.dropna(subset =['ocr']) # remove lines with empty ocr field
    df = df[~df['date'].str.contains('date')] #remove duplicate header rows
    return df

# %%
nrc_df = load_df('nrc')
# Out:
# imported nrc articles

# %%
nrc_pred = svc_randsearch.predict(nrc_df['ocr'])

# %%
nrc_df['recipe'] = nrc_pred

# %%
nrc_df.recipe.value_counts()
# Out:
# articles    954515
# recipes       3764
# Name: recipe, dtype: int64

# %%
nrc_recipes = pd.read_csv('./data/nrc_clean_recipes.csv', index_col=0)
nrc_recipes['date'] = pd.to_datetime(nrc_recipes['date'])
nrc_recipes = nrc_recipes.set_index(['date'], drop=False)
nrc_recipes.recipe.value_counts()
nrc_recipes['recipe'][nrc_recipes['recipe'] == 1].resample('12M').count().plot()

nrc_df['date'] = pd.to_datetime(nrc_df['date'])
nrc_df = nrc_df.set_index(['date'], drop=False)
nrc_df['recipe'][nrc_df.recipe == 'recipes'].resample('12M').count().plot()

# %%
nrc_df['date'] = pd.to_datetime(nrc_df['date'])
nrc_df = nrc_df.set_index(['date'], drop=False)
nrc_df[nrc_df.recipe == 'recipes'].resample('12M').count().plot()

# %%
vk_df = load_df('volkskrant')
# Out:
# imported volkskrant articles

# %%
vk_pred = svc_randsearch.predict(vk_df['ocr'])

# %%
vk_df['recipe'] = vk_pred
vk_df.recipe.value_counts()

# %%
# Out:
# articles    2251278
# recipes       13270
# Name: recipe, dtype: int64

# %%
vk_df
# Out:
#             date  page      size     w     h  \
# 0     1957-09-30     1   7139437  2789  3121
# 1     1957-09-30     1   1790036  1397  1375
# 2     1957-09-30     1   3351352  4170  3789
# 3     1957-09-30     1   2641385  2736  1847
# 4     1957-09-30     1    857225   657  1494
# 5     1957-09-30     1   1132864  1383  1167
# 6     1957-09-30     1    308359   681   468
# 7     1957-09-30     1   1003727  2744  1225
# 8     1957-09-30     1    811535  1387  1168
# 9     1957-09-30     1   1500528  1381  1491
# 10    1957-09-30     1   1317686   691  2001
# 11    1957-09-30     1    395810   682   600
# 12    1957-09-30     1   1056455   688  1561
# 13    1957-09-30     2   3669676  1410  2623
# 14    1957-09-30     2   4490108  2098  2804
# 15    1957-09-30     2    366552   686   553
# 16    1957-09-30     2   1242593   682  1867
# 17    1957-09-30     2    244679   680   369
# 18    1957-09-30     2   4198223  2815  1682
# 19    1957-09-30     2    305450   675   475
# 20    1957-09-30     2   2293916  1390  1776
# 21    1957-09-30     2   2047773  1389  1642
# 22    1957-09-30     2   1287310   687  1905
# 23    1957-09-30     2    861079   698  1266
# 24    1957-09-30     2   1096900   691  1598
# 25    1957-09-30     3   1674577   690  2469
# 26    1957-09-30     3    265298   683   396
# 27    1957-09-30     3   6132601  2095  3797
# 28    1957-09-30     3   2476783  1390  2870
# 29    1957-09-30     3    793848   681  1215
# ...          ...   ...       ...   ...   ...
# 47852 1981-09-26    55    112459   475   254
# 47853 1981-09-26    55     58764   477   139
# 47854 1981-09-26    55    422657   372  1148
# 47855 1981-09-26    61  14428273  4575  4335
# 47856 1981-09-26    61   2356433  1428  2601
# 47857 1981-09-26    61   3064643  2286  2584
# 47858 1981-09-26    61    989864  1496  2580
# 47859 1981-09-26    61   2770291  1504  2583
# 47860 1981-09-26    61   1425848  2943  3057
# 47861 1981-09-26    62  11511523  4598  2974
# 47862 1981-09-26    62   3915006  1291  3450
# 47863 1981-09-26    62   1584063  1496  3286
# 47864 1981-09-26    62   1452798   722  2067
# 47865 1981-09-26    62    987977  1493  3287
# 47866 1981-09-26    62   3491447  1479  3293
# 47867 1981-09-26    63  33556762  4558  6298
# 47868 1981-09-26    65  26662906  4523  6309
# 47869 1981-09-26    67   2805958  2075  1762
# 47870 1981-09-26    67  16843686  4555  6288
# 47871 1981-09-26    67    856573   771  1621
# 47872 1981-09-26    67    354143  1584  1950
# 47873 1981-09-26    67    466254   759   683
# 47874 1981-09-26    67    377815   755   568
# 47875 1981-09-26    67    859848  1589  1938
# 47876 1981-09-26    67   2035592  1613  1983
# 47877 1981-09-26    67     93313   752   190
# 47878 1981-09-26    69   6115996  3073  2196
# 47879 1981-09-26    69  11326230  3059  4234
# 47880 1981-09-26    71  16321809  4657  3944
# 47881 1981-09-26    71   9862574  4605  2340
#
#                                                  ocr_url  \
# 0      http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 1      http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 2      http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 3      http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 4      http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 5      http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 6      http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 7      http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 8      http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 9      http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 10     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 11     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 12     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 13     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 14     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 15     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 16     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 17     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 18     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 19     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 20     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 21     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 22     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 23     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 24     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 25     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 26     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 27     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 28     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# 29     http://resolver.kb.nl/resolve?urn=ABCDDD:01084...
# ...                                                  ...
# 47852  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47853  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47854  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47855  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47856  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47857  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47858  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47859  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47860  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47861  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47862  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47863  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47864  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47865  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47866  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47867  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47868  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47869  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47870  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47871  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47872  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47873  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47874  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47875  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47876  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47877  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47878  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47879  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47880  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
# 47881  http://resolver.kb.nl/resolve?urn=ABCDDD:01087...
#
#                                                      ocr    recipe
# 0      Weekeind-feest in verkeerschaos ontaard STROOM...  articles
# 1      „Tunnel was circus; men stond graag in de rij”...  articles
# 2      Sein op groen In de stationswachtkamer van Haa...  articles
# 3      Wèg varret schip West-Duitsland, dat de *tig s...  articles
# 4      Ballonnen te snel voor tunnelbouwers (Van onze...  articles
# 5      Faubus overweegt sluiting van school in Little...  articles
# 6      Brand op „Willem Ruys” ROTTERDAM, 29 sept. — T...  articles
# 7      „PAMIR” GING ONBESCHADIGD ONDER Overlevenden: ...  articles
# 8      Hallucinaties De volgende nacht stierven nog t...  articles
# 9      Op laatste dag van termijn: Mijnindustrie hoor...  articles
# 10     Ondergronders wel Men verwacht, dat de ministe...  articles
# 11     VRAGEN VAN KAMERLID De overheidssalarissen (Va...  articles
# 12     Mooiste poollicht sinds jaren (Van onze weerku...  articles
# 13     VANDAAG... AMSTERDAM TONEEL. Stadssrhouwhurg: ...  articles
# 14     UITSTEKENDE PREMIERE VAN „OOM WANJA” Ned. Come...  articles
# 15     Paus woont de opening Radio-Anno Santo bij VAT...  articles
# 16     Orkest en dirigent „overbodig” Door de uitvind...  articles
# 17     STANDARD OIL VERGROOT AANDELENKAPITAAL NEW VOR...  articles
# 18     de moordbriade zoekt het uit LTIJ zag Dolan in...  articles
# 19     Vlootgeestelijken confereren (Van onze corresp...  articles
# 20     Afscheid van bekende radiostern RITTER-PRIJS V...  articles
# 21     Opvoering vol toewijding van Yemenitisch balle...  articles
# 22     „Onder verdenking” vol spanning Stuk: „Onder v...  articles
# 23     Tussen Rome en Napels Originele Laokoon gevond...  articles
# 24     Examens ROTTERDAM. 28 sept. Boon, Hogeschool -...  articles
# 25     op de korte golf ♦ Bij de aanbesteding van het...  articles
# 26     JONGETJE VERDRONKEN ROTTERDAM, 29 sept. — Vanm...  articles
# 27     Miljoenen-project voor priester-opleiding Bisd...  articles
# 28     Openhartige brief van mgr Jansen Priester-type...  articles
# 29     Luxemburgse prinsen reizen via Soestdijk KONIN...  articles
# ...                                                  ...       ...
# 47852  DOW JONES INDEX 22/9 23/9 24/9 Industrieën 845...  articles
# 47853  STANDARD AND POORS industrieën 130.53 129.39 1...  articles
# 47854  INCOURANTE FONDSEN Opgave D W Brand NCB-inda» ...  articles
# 47855  Kan een moordenaar schrijver worden of blijft ...  articles
# 47856  Massa-lectuur Jht •' 's, aandacht en massale a...  articles
# 47857  Literatuur Het moderne boek over moordenaars d...  articles
# 47858  Jack Henry Abbott In 1977, tijdens het werk aa...  articles
# 47859  Gevangenisbrieven Een ander boek met dezelfde ...  articles
# 47860  De bijbel als wapen In de eenzaamheid van de o...  articles
# 47861  Denk om de buren De vlammenwerper Je moet nooi...  articles
# 47862  Jan van Lieshout Over de schreef De letters di...  articles
# 47863  Haat ' Zowel Jackson als Abbott werden op de b...  articles
# 47864  Wereldrevolutie George Jackson werd een voorve...  articles
# 47865  Hartekreten als handelswaar In het voorbericht...  articles
# 47866  De volgende moord Op papier werkt de opeenstap...  articles
# 47867  30 jaar TV: Gelden populariteit, er leek geen ...  articles
# 47868  De grootste zondebok van de wereld wil nog een...  articles
# 47869  Je weet het hè. De deur staat hier always open...  articles
# 47870  e popgroep Parachute en e achterkant van het s...  articles
# 47871  DE MEDIA door Peter van Bueren Rotterdam De TR...  articles
# 47872  Kunstig In de omroepgidsen veel aandacht voor ...  articles
# 47873  Bagger m Televizier-AVRO-bode een verslag van ...  articles
# 47874  Politie In evangelische kringen is ook het 27 ...  articles
# 47875  Juliana Nederland blijft een koninkrijk. Wie n...  articles
# 47876  Afwassen Van de chique bladen blijft Avenue tu...  articles
# 47877  Snor En nu de snor van Harmen Siezen zo zoetje...  articles
# 47878  Niet alleen Jeanne d'Arc was een kerel Als de ...  articles
# 47879  'Ook de cultuur wordt ingelijfd' „Elk schilder...  articles
# 47880  Christie's, het casino van de kunstminnaar )on...  articles
# 47881  Begrafenisondermeners onderzoeken lijkverbrand...  articles
#
# [2264548 rows x 8 columns]

# %%
vk_df['date'] = pd.to_datetime(vk_df['date'])
vk_df = vk_df.set_index(['date'], drop=False)
vk_df[vk_df.recipe == 'recipes'].resample('12M').count().plot()

# %%
vk_recipes = pd.read_csv('./data/vk_clean_recipes.csv', index_col=0)
vk_recipes['date'] = pd.to_datetime(vk_recipes['date'])
vk_recipes = vk_recipes.set_index(['date'], drop=False)
vk_recipes.recipe.value_counts()
vk_df[vk_df.recipe == 'recipes'].resample('12M').count().plot()
vk_recipes['recipe'][vk_recipes['recipe'] == 1].resample('12M').count().plot()

# %%
vk_recipes_classified = vk_df[vk_df.recipe == 'recipes']
vk_recipes_classified.to_csv('data/vk_recipes_classified.csv')

# %%
trouw_df = load_df('trouw')
# Out:
# /Users/melvinwevers/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: DtypeWarning: Columns (1,2,3,4,5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   # This is added back by InteractiveShellApp.init_path()
# imported trouw articles

# %%
trouw_pred = svc_randsearch.predict(trouw_df['ocr'])

# %%
trouw_df['recipe'] = trouw_pred
trouw_df.recipe.value_counts()
# Out:
# articles    2618648
# recipes        5937
# Name: recipe, dtype: int64

# %%
trouw_recipes = pd.read_csv('./data/trouw_clean_recipes.csv', index_col=0)
trouw_recipes['date'] = pd.to_datetime(trouw_recipes['date'])
trouw_recipes = trouw_recipes.set_index(['date'], drop=False)
trouw_recipes.recipe.value_counts()
# Out:
# 1    2568
# 0     926
# Name: recipe, dtype: int64

# %%
trouw_df['date'] = pd.to_datetime(trouw_df['date'])
trouw_df = trouw_df.set_index(['date'], drop=False)
trouw_df[trouw_df.recipe == 'recipes'].resample('12M').count().plot()

# %%
trouw_recipes_classified = trouw_df[trouw_df.recipe == 'recipes']
trouw_recipes_classified.to_csv('data/trouw_recipes_classified.csv')

# %%
parool_df = load_df('parool')
# Out:
# /Users/melvinwevers/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: DtypeWarning: Columns (1,2,3,4,5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   # This is added back by InteractiveShellApp.init_path()
# imported parool articles

# %%
parool_pred = svc_randsearch.predict(parool_df['ocr'])

# %%
parool_df['recipe'] = parool_pred
parool_df.recipe.value_counts()
# Out:
# articles    2609030
# recipes        4440
# Name: recipe, dtype: int64

# %%
parool_recipes = pd.read_csv('./data/parool_clean_recipes.csv')
parool_recipes['date'] = parool_recipes['date'].astype('datetime64[ns]')
parool_recipes['date'] = pd.to_datetime(parool_recipes['date'])
parool_recipes = parool_recipes.set_index(['date'], drop=False)
parool_recipes.recipe.value_counts()
# Out:
# 1    1481
# 0     971
# Name: recipe, dtype: int64

# %%
parool_df['date'] = pd.to_datetime(parool_df['date'])
parool_df = parool_df.set_index(['date'], drop=False)
parool_df[parool_df.recipe == 'recipes'].resample('12M').count().plot()

# %%
parool_recipes_classified = parool_df[parool_df.recipe == 'recipes']
parool_recipes_classified.to_csv('data/parool_recipes_classified.csv')

# %%
from matplotlib.ticker import MaxNLocator
import numpy as np

fig, ax = plt.subplots(1, 4, figsize=(15,5), sharex=True)

nrc_recipes['recipe'][nrc_recipes['recipe'] == 1].resample('12M').count().plot(ax=ax[0], title="NRC")
nrc_df['recipe'][nrc_df.recipe == 'recipes'].resample('12M').count().plot(ax=ax[0])

vk_recipes['recipe'][vk_recipes['recipe'] == 1].resample('12M').count().plot(ax=ax[1])
vk_df['recipe'][vk_df.recipe == 'recipes'].resample('12M').count().plot(ax=ax[1], title="Volkskrant")

trouw_recipes['recipe'][trouw_recipes['recipe'] == 1].resample('12M').count().plot(ax=ax[2], title = 'Trouw')
trouw_df['recipe'][trouw_df.recipe == 'recipes'].resample('12M').count().plot(ax=ax[2])

parool_recipes['recipe'][parool_recipes['recipe'] == 1].resample('12M').count().plot(ax=ax[3], title = 'Parool')
parool_df['recipe'][parool_df.recipe == 'recipes'].resample('12M').count().plot(ax=ax[3])

plt.tight_layout
plt.savefig('classifier_newspapers.png', dpi=300)

# %%
ax[0]

# %%
trouw_df
# Out:
#                  date page     size     w     h  \
# date
# 1990-02-05 1990-02-05    1  3112115  2918  2057
# 1990-02-05 1990-02-05    1  1043327   541  2019
# 1990-02-05 1990-02-05    1  6639654  2336  3089
# 1990-02-05 1990-02-05    1  1936138  1730  2727
# 1990-02-05 1990-02-05    1  1447270  1735   986
# 1990-02-05 1990-02-05    1  1574001  1731  1014
# 1990-02-05 1990-02-05    1  1337808  1669   943
# 1990-02-05 1990-02-05    1  1266937  1652  1865
# 1990-02-05 1990-02-05    2  1544810  1134  2720
# 1990-02-05 1990-02-05    2   893685  1132  2711
# 1990-02-05 1990-02-05    2  5299437  2328  2728
# 1990-02-05 1990-02-05    2  2010060  1728  2718
# 1990-02-05 1990-02-05    2   130641   831   270
# 1990-02-05 1990-02-05    2   217210  1137   277
# 1990-02-05 1990-02-05    2  5147128  2353  3064
# 1990-02-05 1990-02-05    2  2253045  3290  2713
# 1990-02-05 1990-02-05    2   323863   531   966
# 1990-02-05 1990-02-05    2   492024  1125  1319
# 1990-02-05 1990-02-05    2   515028   851  1316
# 1990-02-05 1990-02-05    2  2942793  1149  3113
# 1990-02-05 1990-02-05    2  3094996  1746  2672
# 1990-02-05 1990-02-05    3  1592446  2549  2202
# 1990-02-05 1990-02-05    3   442493  1135   642
# 1990-02-05 1990-02-05    3  1556582  1142  2026
# 1990-02-05 1990-02-05    3  1060079  1132  1019
# 1990-02-05 1990-02-05    3  1526883  1631  2396
# 1990-02-05 1990-02-05    3  1104891  1116  2693
# 1990-02-05 1990-02-05    3  1709946  1104  2681
# 1990-02-05 1990-02-05    3   265604   531   527
# 1990-02-05 1990-02-05    3  1661674  1163  2032
# ...               ...  ...      ...   ...   ...
# 1956-05-09 1956-05-09   13   667056   678   997
# 1956-05-09 1956-05-09   13   380262   682   573
# 1956-05-09 1956-05-09   13   290169  1661   402
# 1956-05-09 1956-05-09   13  2467898  2996  1111
# 1956-05-09 1956-05-09   13   651837   686   981
# 1956-05-09 1956-05-09   13  1375855  1388  1358
# 1956-05-09 1956-05-09   13  1001342  1289  1412
# 1956-05-09 1956-05-09   13   531405   682   803
# 1956-05-09 1956-05-09   13   387016   686   574
# 1956-05-09 1956-05-09   13  1032193  1384   991
# 1956-05-09 1956-05-09   13   497913   678   745
# 1956-05-09 1956-05-09   13   120536   578   242
# 1956-05-09 1956-05-09   13   134280   578   256
# 1956-05-09 1956-05-09   13   501414  1199  1102
# 1956-05-09 1956-05-09   13  1534977  1388  1377
# 1956-05-09 1956-05-09   13   160158   557   320
# 1956-05-09 1956-05-09   13   614240   678   972
# 1956-05-09 1956-05-09   13  1563405  1387  1495
# 1956-05-09 1956-05-09   13   890269  1383   865
# 1956-05-09 1956-05-09   13  1432170  1392  1168
# 1956-05-09 1956-05-09   13   921842  1384  1024
# 1956-05-09 1956-05-09   13   292435   679   460
# 1956-05-09 1956-05-09   13   496504   694   732
# 1956-05-09 1956-05-09   13   128275   580   241
# 1956-05-09 1956-05-09   13   150802   694   218
# 1956-05-09 1956-05-09   13    82460   580   167
# 1956-05-09 1956-05-09   13    40980   580    98
# 1956-05-09 1956-05-09   13    46291   581   101
# 1956-05-09 1956-05-09   13   501671  1207  1104
# 1956-05-09 1956-05-09   13   419181   592   771
#
#                                                       ocr_url  \
# date
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1990-02-05  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# ...                                                       ...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
# 1956-05-09  http://resolver.kb.nl/resolve?urn=ABCDDD:01082...
#
#                                                           ocr    recipe
# date
# 1990-02-05  Sowjets eisen democratie Betogers in Moskou ze...  articles
# 1990-02-05  Voor einde van dit jaar nog CVSE-top over Duit...  articles
# 1990-02-05  Harttransplantatie tot 55 jaar Van een onzer v...  articles
# 1990-02-05  Irritatie In regeringskringen bestaat irritati...  articles
# 1990-02-05  PvdA uit raad Winschoten Grootste partij lamge...  articles
# 1990-02-05  Terroristen doden in Egypte acht Israëliërs CA...  articles
# 1990-02-05  'Is het offer het wei waard?' Mandela in cel g...  articles
# 1990-02-05  Mandela eist opheffen noodtoestand Zuid-Afrika...  articles
# 1990-02-05  Niet te zwaar Daar komt bij, en dat vindt Fons...  articles
# 1990-02-05  'Te nauwe jas' Fons kwam na de middelbare scho...  articles
# 1990-02-05  Twijfel In een van zijn boekjes zegt Fons: 'Ho...  articles
# 1990-02-05  potentilla erecta (l7) En, Iwan Soesanin, nog ...  articles
# 1990-02-05  PERSONALIA Mevrouw S. M. Dekker is met ingang ...  articles
# 1990-02-05  Overleden Op 73-jarige leeftijd is vrijdag de ...  articles
# 1990-02-05  MENSEN OP MAANDAG bijdrage: arend evenhuis emo...  articles
# 1990-02-05  Mensen 'Ik was een doorgeefluikje' Cabaretier ...  articles
# 1990-02-05  TV-films Vandaag 'Santa Fe trial' (Nederland 1...  articles
# 1990-02-05  Dinsdag 'The city never sleeps' (Engeland 2, 1...  articles
# 1990-02-05  Woensdag 'Dinner at the ritz' (Nederland 2, 16...  articles
# 1990-02-05  Mink van Rijsdijk Voor aap Een hele poos geled...  articles
# 1990-02-05  Donderdag 'The killers'( Duitsland 3, 20.00 uu...  articles
# 1990-02-05  Binnenland Nu klacht in Genève over kruisraket...  articles
# 1990-02-05  Levensbedreigend „In redelijkheid kan niet ont...  articles
# 1990-02-05  Chauffeurs in actie tegen verkoop Philips-onde...  articles
# 1990-02-05  Vrouw werkte jaren zonder papieren als keuring...  articles
# 1990-02-05  Bezem moet nu door stal van PvdA in Winschoten...  articles
# 1990-02-05  Geen liefhebber Een PvdA-zetel is momenteel on...  articles
# 1990-02-05  'Machiavelli' Ook burgemeester Postma -die van...  articles
# 1990-02-05  'Slechte zaak' Gedeputeerde Vos hoopt nu dat b...  articles
# 1990-02-05  Inspectie kan omstreden arts alleen maar verzo...  articles
# ...                                                       ...       ...
# 1956-05-09  Goederentermijnmarkt AMSTERDAM, 8 mei. — , Cac...  articles
# 1956-05-09  Amsterdamse wisselkoersen 8 mei — Contante koe...  articles
# 1956-05-09  PASSAGIERSSCHEPEN SCHEPEN OP WERELDZEEËN _».-!...  articles
# 1956-05-09  GROTE VAART fel? s s? -ïra—. K,.!ti_».'s ..van...  articles
# 1956-05-09  Chevrolet beperkt produktie Chevrolet, een van...  articles
# 1956-05-09  Vestigingen Nederlanden 1845 in Canada voldoen...  articles
# 1956-05-09  Bedrijfsleven rapporteert: Inschrijving AKU op...  articles
# 1956-05-09  N.-Europ. Houthandel vergrootte omzet De explo...  articles
# 1956-05-09  Un. Reassurantie behaalde hoger premie-inkomen...  articles
# 1956-05-09  E.G.K.S. sluit overeenkomst met Zwitserland De...  articles
# 1956-05-09  EQUITABLE GAS CO. Met ingang van 16 mei zullen...  articles
# 1956-05-09  SLEEPVAART Hla 11 ken burg met sleep pass. 7 L...  articles
# 1956-05-09  WATERSTANDEN 8 mei — Mannheim 8.59 (—0.09., Ka...  articles
# 1956-05-09  PAARDEN EN VEE ROTTERDAM, 8 mei — Aanvoer* 620...  articles
# 1956-05-09  Duitsland overweegt maatregelen tegen hoogconj...  articles
# 1956-05-09  Trouw Beursindex Datum mtaaj Lndu» tia_a.- Wie...  articles
# 1956-05-09  Giessen Scheepswerf weer 12 % C. van der Giess...  articles
# 1956-05-09  Klantenobligaties Albert Heyn komen aan de beu...  articles
# 1956-05-09  Noorse staalfabriek wil lening in Nederland sl...  articles
# 1956-05-09  EFFECTENBEURS GEDRUKT AMSTERDAM, 8 mei. — Gist...  articles
# 1956-05-09  Mode gaat bij schoenen een steeds grotere rol ...  articles
# 1956-05-09  Betaalbaarstelling Ned. Kabelfabriek — 35 (eer...  articles
# 1956-05-09  Weekstaat Nederl. Bank (in duizenden _uldemi A...  articles
# 1956-05-09  MARKTBERICHTEN GRANEN EN ZADEN GRONINGEN, 8 me...  articles
# 1956-05-09  NED. FONDSEN IN NEW VORK Koninklijke Olie note...  articles
# 1956-05-09  PLUIMVEE PUR-DEREND, 8 mei — Aangevoerd: 2,700...  articles
# 1956-05-09  EIEREN PURMEREND, 8 mei — Aangevoerd: 12.(100 ...  articles
# 1956-05-09  BOTER EN KAAS BODEGRAVEN, 8 mei — Aanvoer: 28 ...  articles
# 1956-05-09  GROENTEN EN FRUIT AMSTERDAM, 7 mei — Per kg: p...  articles
# 1956-05-09  VISSERIJBERICHTEN. URK, 8 mei — Door 85 vaartu...  articles
#
# [2624585 rows x 8 columns]
